# %% [markdown]
# <a href="https://colab.research.google.com/github/sbshreaballal-max/Gener8/blob/main/notebooks/news_brief_updates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries (Colab-safe)
# !pip install feedparser pyyaml
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=6b2c9ecb6b8b550670cece4c7aaa9ce3f436fc1da40402dfb8f49b4c7171ff07
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0

# %% [markdown]
# ## 📥 Load Project Code from GitHub
#
# This notebook pulls all logic (feeds, filtering, summarization) from GitHub.

# %%
# Replace with your actual GitHub username + repo name
# !git clone https://github.com/sbshreaballal-max/Gener8.git
# %cd Gener8
# Out:
# fatal: destination path 'Gener8' already exists and is not an empty directory.
# /content/Gener8

# %% [markdown]
# ## 🔧 Import Project Modules

# %%
from src.feeds import fetch_articles
from src.personas import load_persona
from src.filter import filter_articles
from src.summarizer import summarize_articles
from src.brief import generate_brief

# %% [markdown]
# ## 👤 Select Persona
#
# Choose the persona YAML file to generate a tailored news brief.

# %%
# Update persona path as needed
persona_path = "personas/ai_opinion_seeker.yaml"
persona = load_persona(persona_path)

persona
# Out:
# {'persona': {'name': 'AI Opinion Seeker',
#   'description': 'A reader interested in perspectives, debates, and societal implications of AI rather than technical details.\n'},
#  'preferences': {'topics': ['AI ethics',
#    'regulation',
#    'societal impact',
#    'AI narratives',
#    'future of work'],
#   'sources': ['TechCrunch', 'Wired', 'MIT Technology Review'],
#   'depth': 'conceptual',
#   'tone': 'reflective',
#   'summary_length': 'short'},
#  'filters': {'include_keywords': ['ethics',
#    'impact',
#    'regulation',
#    'opinion',
#    'future',
#    'courtroom',
#    'research',
#    'trade'],
#   'exclude_keywords': ['API', 'benchmark', 'training loss']}}

# %% [markdown]
# ## 🌐 Fetch Articles from RSS Feeds
#
# Articles are pulled from open news sources for the past 30 days.

# %%
RSS_FEEDS = [
    "https://techcrunch.com/feed/",
    "https://www.theverge.com/rss/index.xml"
]

articles = []
for feed in RSS_FEEDS:
    articles.extend(fetch_articles(feed, days_back=30))

print(f"Total articles fetched: {len(articles)}")
# Out:
# Total articles fetched: 30

# %% [markdown]
# ## 🎯 Filter Articles by Persona Relevance

# %%
filtered_articles = filter_articles(articles, persona['filters'])
print(f"Relevant articles for persona: {len(filtered_articles)}")
# Out:
# Relevant articles for persona: 4

# %% [markdown]
# ## 🧠 Generate Persona-Based Summary

# %%
summary = summarize_articles(filtered_articles)
print(summary)
# Out:
# Welcome back to TechCrunch Mobility, your hub for all things “future of transportation.” OpenAI says that users impacted by the ads will have some control over what they see. Asus chairman Jonney Shih told Taiwan's Inside that the company is done making phones for now, marking the end of its Zenfone and ROG Phone lines. "Asus will no longer add new mobile phone models in the future," Shih reportedly said (translated with Google Translate).

# %% [markdown]
# ## 📰 Generate Final News Brief

# %%
brief = generate_brief(persona, summary, filtered_articles)
print(brief)
# Out:
# # 📰 AI News Brief — AI Opinion Seeker
# **Date:** 2026-01-19
#
# ## TL;DR
# Welcome back to TechCrunch Mobility, your hub for all things “future of transportation.” OpenAI says that users impacted by the ads will have some control over what they see. Asus chairman Jonney Shih told Taiwan's Inside that the company is done making phones for now, marking the end of its Zenfone and ROG Phone lines. "Asus will no longer add new mobile phone models in the future," Shih reportedly said (translated with Google Translate).
#
# ## Top Articles
#
# ### TechCrunch Mobility: ‘Physical AI’ enters the hype machine
# Welcome back to TechCrunch Mobility, your hub for all things “future of transportation.”
#
# 🔗 https://techcrunch.com/2026/01/18/techcrunch-mobility-physical-ai-enters-the-hype-machine/
#
# ### ChatGPT users are about to get hit with targeted ads
# OpenAI says that users impacted by the ads will have some control over what they see.
#
# 🔗 https://techcrunch.com/2026/01/16/chatgpt-users-are-about-to-get-hit-with-targeted-ads/
#
# ### Asus may have made its last phone
# Asus chairman Jonney Shih told Taiwan's Inside that the company is done making phones for now, marking the end of its Zenfone and ROG Phone lines. "Asus will no longer add new mobile phone models in the future," Shih reportedly said (translated with Google Translate). He didn't entirely rule out a return though, instead saying [&#8230;]
#
# 🔗 https://www.theverge.com/news/864116/asus-may-have-made-its-last-phone
#
# ### Why Coinbase derailed the crypto industry’s political future
# January was going to be a landmark month for the crypto industry. The Senate would start negotiating the finer details of the CLARITY Act, a major law that would finally enshrine the fundamental structure of how the crypto market could legally operate in the United States: what digital assets counted as a security versus a [&#8230;]
#
# 🔗 https://www.theverge.com/policy/864008/senate-clarity-act-coinbase-crypto-market

# %% [markdown]
# ## 🔜 Next Steps
#
# - Add more personas
# - Improve semantic relevance scoring
# - Add UI for persona selection
# - Export brief to Markdown or email format
